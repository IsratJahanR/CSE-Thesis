# %%
import pandas as pd
url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQ4lmIMpD1jqLXnTCkBZP2w9Tb26Urkl2JghQUTz8id3dGVR1Z1zMLqOS4QtzFhkJ33Q1dHtQsvl-6H/pub?output=csv"
url = 'CSE Thesis - Sheet1.csv'
df = pd.read_csv(url)
df.columns = df.iloc[0]  # Set the first row as the header
df = df.drop(index=0)    # Drop the first row
df.reset_index(drop=True, inplace=True)
df
# Out:
# 0                Date name e-mail  gender year  cgpa  \
# 0    2024-04-24 09:30  NaN    NaN  Female  4th  3.84
# 1    2024-04-24 09:58  NaN    NaN    Male  4th   2.5
# 2    2024-04-24 09:58  NaN    NaN    Male  4th  3.34
# 3    2024-04-24 10:18  NaN    NaN    Male  4th  3.78
# 4    2024-04-24 10:18  NaN    NaN    Male  4th     3
# ..                ...  ...    ...     ...  ...   ...
# 463  2024-04-27 01:06  NaN    NaN  Female  4th   3.2
# 464  2024-04-25 23:50  NaN    NaN    Male  4th  3.64
# 465  2024-04-26 05:37  NaN    NaN    Male  4th   3.7
# 466  2024-04-26 08:02  NaN    NaN    Male  4th   3.3
# 467  2024-04-26 11:22  NaN    NaN  Female  4th  3.79
#
# 0                                      university_name Critical Thinking  \
# 0    Bangabandhu Sheikh Mujibur Rahman Science & Te...      Intermediate
# 1    Bangabandhu Sheikh Mujibur Rahman Science & Te...             Basic
# 2    Bangabandhu Sheikh Mujibur Rahman Science & Te...      Intermediate
# ...

# %%
df.shape
# Out:
# (468, 27)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(by='Date')
df
# Out:
# 0                  Date name e-mail  gender year  cgpa  \
# 0   2024-04-24 09:30:00  NaN    NaN  Female  4th  3.84
# 1   2024-04-24 09:58:00  NaN    NaN    Male  4th   2.5
# 2   2024-04-24 09:58:00  NaN    NaN    Male  4th  3.34
# 3   2024-04-24 10:18:00  NaN    NaN    Male  4th  3.78
# 4   2024-04-24 10:18:00  NaN    NaN    Male  4th     3
# ..                  ...  ...    ...     ...  ...   ...
# 427 2024-11-14 05:58:00  NaN    NaN    Male  4th  3.88
# 428 2024-11-14 06:01:00  NaN    NaN    Male  4th  3.55
# 429 2024-11-14 06:02:00  NaN    NaN    Male  4th  3.39
# 430 2024-11-21 03:38:00  NaN    NaN    Male  4th  3.33
# 431 2024-11-21 03:45:00  NaN    NaN    Male  4th  2.98
#
# 0                                      university_name Critical Thinking  \
# 0    Bangabandhu Sheikh Mujibur Rahman Science & Te...      Intermediate
# 1    Bangabandhu Sheikh Mujibur Rahman Science & Te...             Basic
# 2    Bangabandhu Sheikh Mujibur Rahman Science & Te...      Intermediate
# ...

# %%
df.drop(['Date','name','e-mail'], axis=1, inplace=True)
df
# Out:
# 0    gender year  cgpa                                    university_name  \
# 0    Female  4th  3.84  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 1      Male  4th   2.5  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 2      Male  4th  3.34  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 3      Male  4th  3.78              United International University (UIU)
# 4      Male  4th     3  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# ..      ...  ...   ...                                                ...
# 427    Male  4th  3.88                      University of Chittagong (CU)
# 428    Male  4th  3.55  American International University-Bangladesh (...
# 429    Male  4th  3.39  American International University-Bangladesh (...
# 430    Male  4th  3.33  Mawlana Bhashani Science & Technology Universi...
# 431    Male  4th  2.98    CCN University of Science & Technology (CCNUST)
#
# 0   Critical Thinking Problem Solving     Team Work Communication Skill  \
# ...

# %%
print(df.duplicated().sum())
# Out:
# 10

# %%
university = df.groupby('university_name').size().reset_index(name='Count')
university = university.sort_values(by='Count',ascending=False)
#print(university)

university.to_csv('university.csv')

# %%
university.shape
# Out:
# (47, 2)

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      367
# Female    101
# Name: count, dtype: int64

# %%
year = df.groupby('year').size().reset_index(name='Count')
year = year.sort_values(by='Count',ascending=False)
year
# Out:
#   year  Count
# 3  4th    362
# 2  3rd     58
# 1  2nd     31
# 0  1st     17

# %%
year.sum()
# Out:
# year     4th3rd2nd1st
# Count             468
# dtype: object

# %%
df.isna().sum()
# Out:
# 0
# gender                                              0
# year                                                0
# cgpa                                                7
# university_name                                     0
# Critical Thinking                                   3
# Problem Solving                                     3
# Team Work                                           2
# Communication Skill                                 5
# Software Engineering Principal                     14
# Data Structure & Algorithm                         11
# Database Management                                12
# Data Analysis                                      24
# Web Developing Skill                               17
# Understanding of computer architecture & System    26
# Understanding Operating System                     20
# Networking Concept                                 30
# Cyber Security                                     42
# ...

# %%
df['year']=df['year'].fillna('4th')
df
# Out:
# 0    gender year  cgpa                                    university_name  \
# 0    Female  4th  3.84  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 1      Male  4th   2.5  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 2      Male  4th  3.34  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 3      Male  4th  3.78              United International University (UIU)
# 4      Male  4th     3  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# ..      ...  ...   ...                                                ...
# 463  Female  4th   3.2               Northern University Bangladesh (NUB)
# 464    Male  4th  3.64                           Comilla University (CoU)
# 465    Male  4th   3.7                           Comilla University (CoU)
# 466    Male  4th   3.3               Northern University Bangladesh (NUB)
# 467  Female  4th  3.79                           Comilla University (CoU)
#
# 0   Critical Thinking Problem Solving     Team Work Communication Skill  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 24 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   gender                                           468 non-null    object
#  1   year                                             468 non-null    object
#  2   cgpa                                             461 non-null    object
#  3   university_name                                  468 non-null    object
#  4   Critical Thinking                                465 non-null    object
#  5   Problem Solving                                  465 non-null    object
#  6   Team Work                                        466 non-null    object
#  7   Communication Skill                              463 non-null    object
#  8   Software Engineering Principal                   454 non-null    object
# ...

# %%
df['publication']=df['publication'].fillna(0)
df['project']=df['project'].fillna(0)
print(df['publication'])
print(df['project'])
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 463    0
# 464    2
# 465    3
# 466    0
# 467    0
# Name: publication, Length: 468, dtype: object
# 0      2
# 1      0
# 2      2
# 3      1
# 4      5
#       ..
# 463    2
# 464    4
# 465    3
# 466    2
# 467    4
# Name: project, Length: 468, dtype: object

# %%
#converted publication and research_paper int int32 form
convert_dict = {'publication': 'int16',
                'project': 'int16',
                'cgpa':'float64'
               }
df = df.astype(convert_dict)
df.sample(10)
# Out:
# 0    gender year  cgpa                                    university_name  \
# 259    Male  4th  2.56  Shahjalal University of Science & Technology (...
# 280    Male  4th  3.71                             Khulna University (KU)
# 162    Male  4th  3.83                        University of Rajshahi (RU)
# 224    Male  4th  3.20  American International University-Bangladesh (...
# 329    Male  4th  3.95                            BRAC University (BRACU)
# 114    Male  3rd  3.00  Mawlana Bhashani Science & Technology Universi...
# 372  Female  4th  3.73  Rajshahi University of Engineering & Technolog...
# 312    Male  4th  3.85                Islamic University, Bangladesh (IU)
# 264    Male  4th  3.56                Islamic University, Bangladesh (IU)
# 127    Male  4th  2.80  Bangabandhu Sheikh Mujibur Rahman Science & Te...
#
# 0   Critical Thinking Problem Solving     Team Work Communication Skill  \
# 259           Advance         Advance  Intermediate        Intermediate
# ...

# %%
print(df.columns)
# Out:
# Index(['gender', 'year', 'cgpa', 'university_name', 'Critical Thinking',
#        'Problem Solving', 'Team Work', 'Communication Skill',
#        'Software Engineering Principal', 'Data Structure & Algorithm',
#        'Database Management', 'Data Analysis', 'Web Developing Skill',
#        'Understanding of computer architecture & System',
#        'Understanding Operating System', 'Networking Concept',
#        'Cyber Security', 'Maching Learning', 'Robotics', 'Research Skill',
#        'publication', 'project', 'Influencing Factor', 'Prefer Job'],
#       dtype='object', name=0)

# %%
project = df.groupby('project').size().reset_index(name='Count')
#year = year.sort_values(by='Count',ascending=False)
project
# Out:
#    project  Count
# 0        0     39
# 1        1     99
# 2        2    135
# 3        3     79
# 4        4     56
# 5        5     45
# 6        6     13
# 7        7      1
# 8       10      1

# %%
publication = df.groupby('publication').size().reset_index(name='Count')
#year = year.sort_values(by='Count',ascending=False)
publication
# Out:
#    publication  Count
# 0            0    314
# 1            1     94
# 2            2     30
# 3            3     18
# 4            4      7
# 5            5      5

# %%
df.describe()
# Out:
# 0            cgpa  publication     project
# count  461.000000   468.000000  468.000000
# mean     3.324403     0.557692    2.457265
# std      0.453738     1.000473    1.577509
# min      0.000000     0.000000    0.000000
# 25%      3.100000     0.000000    1.000000
# 50%      3.380000     0.000000    2.000000
# 75%      3.600000     1.000000    3.000000
# max      4.000000     5.000000   10.000000

# %%
df.isna().sum()
# Out:
# 0
# gender                                              0
# year                                                0
# cgpa                                                7
# university_name                                     0
# Critical Thinking                                   3
# Problem Solving                                     3
# Team Work                                           2
# Communication Skill                                 5
# Software Engineering Principal                     14
# Data Structure & Algorithm                         11
# Database Management                                12
# Data Analysis                                      24
# Web Developing Skill                               17
# Understanding of computer architecture & System    26
# Understanding Operating System                     20
# Networking Concept                                 30
# Cyber Security                                     42
# ...

# %%
df['cgpa'].isna().sum()
# Out:
# 7

# %%
df['cgpa'].mean()
# Out:
# 3.3244034707158354

# %%
df['cgpa']=df['cgpa'].fillna(df['cgpa'].mean())

# %%
df
# Out:
# 0    gender year  cgpa                                    university_name  \
# 0    Female  4th  3.84  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 1      Male  4th  2.50  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 2      Male  4th  3.34  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 3      Male  4th  3.78              United International University (UIU)
# 4      Male  4th  3.00  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# ..      ...  ...   ...                                                ...
# 463  Female  4th  3.20               Northern University Bangladesh (NUB)
# 464    Male  4th  3.64                           Comilla University (CoU)
# 465    Male  4th  3.70                           Comilla University (CoU)
# 466    Male  4th  3.30               Northern University Bangladesh (NUB)
# 467  Female  4th  3.79                           Comilla University (CoU)
#
# 0   Critical Thinking Problem Solving     Team Work Communication Skill  \
# ...

# %%
df['Prefer Job'].isna().sum()
# Out:
# 9

# %%
df['Prefer Job']=df['Prefer Job'].fillna('Other')
df['Influencing Factor']=df['Influencing Factor'].fillna('Other Factor')

# %%
df.isna().sum()
# Out:
# 0
# gender                                              0
# year                                                0
# cgpa                                                0
# university_name                                     0
# Critical Thinking                                   3
# Problem Solving                                     3
# Team Work                                           2
# Communication Skill                                 5
# Software Engineering Principal                     14
# Data Structure & Algorithm                         11
# Database Management                                12
# Data Analysis                                      24
# Web Developing Skill                               17
# Understanding of computer architecture & System    26
# Understanding Operating System                     20
# Networking Concept                                 30
# Cyber Security                                     42
# ...

# %%
df=df.fillna(0)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df=df.replace({'Basic','basic'}, 1)
df=df.replace({'Intermediate','intermediate'},2)
df=df.replace({'Advance','advance'},3)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 24 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   gender                                           468 non-null    object
#  1   year                                             468 non-null    object
#  2   cgpa                                             468 non-null    float64
#  3   university_name                                  468 non-null    object
#  4   Critical Thinking                                468 non-null    int64
#  5   Problem Solving                                  468 non-null    int64
#  6   Team Work                                        468 non-null    int64
#  7   Communication Skill                              468 non-null    int64
#  8   Software Engineering Principal                   468 non-null    int64
# ...

# %%
df['gender'] = df['gender'].map({'Male': 0, 'Female': 1})
df['year'] = df['year'].map({'1st': 1, '2nd': 2, '3rd': 3, '4th': 4})

# One-Hot Encoding (Optional)
#gender_one_hot = pd.get_dummies(df['gender'], prefix='gender')
#year_one_hot = pd.get_dummies(df['year'], prefix='year')

# Concatenate One-Hot Encoded columns if needed
#df = pd.concat([df, gender_one_hot, year_one_hot], axis=1)
df
# Out:
# 0    gender  year  cgpa                                    university_name  \
# 0         1     4  3.84  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 1         0     4  2.50  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 2         0     4  3.34  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 3         0     4  3.78              United International University (UIU)
# 4         0     4  3.00  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# ..      ...   ...   ...                                                ...
# 463       1     4  3.20               Northern University Bangladesh (NUB)
# 464       0     4  3.64                           Comilla University (CoU)
# 465       0     4  3.70                           Comilla University (CoU)
# 466       0     4  3.30               Northern University Bangladesh (NUB)
# 467       1     4  3.79                           Comilla University (CoU)
#
# ...

# %%
df['Research Skill'].value_counts()
# Out:
# Research Skill
# 1    255
# 2     90
# 0     80
# 3     43
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 24 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   gender                                           468 non-null    int64
#  1   year                                             468 non-null    int64
#  2   cgpa                                             468 non-null    float64
#  3   university_name                                  468 non-null    object
#  4   Critical Thinking                                468 non-null    int64
#  5   Problem Solving                                  468 non-null    int64
#  6   Team Work                                        468 non-null    int64
#  7   Communication Skill                              468 non-null    int64
#  8   Software Engineering Principal                   468 non-null    int64
# ...

# %%
df = df.rename(columns={
    'Data Analysis': 'Data Analysis skill',
    'Cyber Security': 'Cyber Security Skill',
    'Maching Learning':'Machine Learning Skill',
    'Robotics':'Robotics Skill'
})

# %%
df.to_csv('clean_data.csv')

# %%
#from pandas_profiling import ProfileReport
#from ydata_profiling import ProfileReport
# Assuming 'df' is your DataFrame
#prof = ProfileReport(df)
#prof.to_file(output_file='summary.html')

# %%
df
# Out:
# 0    gender  year  cgpa                                    university_name  \
# 0         1     4  3.84  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 1         0     4  2.50  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 2         0     4  3.34  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# 3         0     4  3.78              United International University (UIU)
# 4         0     4  3.00  Bangabandhu Sheikh Mujibur Rahman Science & Te...
# ..      ...   ...   ...                                                ...
# 463       1     4  3.20               Northern University Bangladesh (NUB)
# 464       0     4  3.64                           Comilla University (CoU)
# 465       0     4  3.70                           Comilla University (CoU)
# 466       0     4  3.30               Northern University Bangladesh (NUB)
# 467       1     4  3.79                           Comilla University (CoU)
#
# ...

# %% [markdown]
# # Remove some Rows

# %%
#multiple_prefs = df[df['Prefer Job'].str.contains('Teaching') ]

#df_cleaned = df[~(df['Prefer Job'].str.contains('UI/UX Designing') )]
#df_cleaned = df[(df['year']==3)]

#df_cleaned.to_csv('clean_data.csv')

# %%
#dff = df.head(300)  
#dff.to_csv('clean_data.csv')
